# %% [markdown]
# # Introduction
#
# Sometimes web pages are build from JavaScript once the document is loaded into the browser.
# An example is http://news.gsu.edu where the news contents it not part of the HTML document, but is rather loaded
# dynamically.
#
# In other cases, user interactions like logging into the site might be required. We demonstrate this on Google Analytics.
#
#
# Here, we need an real web-browser to render the page before we can extract any data points.
# The browser can be either
# - headless https://en.wikipedia.org/wiki/Headless_browser ,or
# - a regular web browser that can be controlled from a program.
#
# This notebook gives an example of using Selenium Web Driver http://www.seleniumhq.org/projects/webdriver/
#
# **Reference:** http://selenium-python.readthedocs.io

# %% [markdown]
# # Install Chrome Driver (macOS)

# %% [raw]
# floyd:~ Peter$ brew install chromedriver
# Updating Homebrew...
# ==> Downloading https://chromedriver.storage.googleapis.com/2.35/chromedriver_ma
# ######################################################################## 100.0%
# ==> Caveats
# To have launchd start chromedriver now and restart at login:
#   brew services start chromedriver
# Or, if you don't want/need a background service you can just run:
#   chromedriver
# ==> Summary
# 🍺  /usr/local/Cellar/chromedriver/2.35: 4 files, 11.3MB, built in 3 seconds
# floyd:~ Peter$ brew services start chromedriver
# ==> Tapping homebrew/services
# Cloning into '/usr/local/Homebrew/Library/Taps/homebrew/homebrew-services'...
# remote: Counting objects: 14, done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 14 (delta 0), reused 9 (delta 0), pack-reused 0
# Unpacking objects: 100% (14/14), done.
# Tapped 0 formulae (43 files, 55.4KB)
# ==> Successfully started `chromedriver` (label: homebrew.mxcl.chromedriver)
# floyd:~ Peter$

# %%
# %%sh
# brew services list
# Out:
# Name         Status  User  Plist
# zookeeper    stopped
# kafka        stopped
# chromedriver started Peter /Users/Peter/Library/LaunchAgents/homebrew.mxcl.chromedriver.plist

# %%
# %%sh
# ##brew serices start chromedriver

# %% [markdown]
# We also need:
# 1. Beautyful Soup `bs4`
# 2. `lxml`

# %% [markdown]
# # Getting Data from Google Analytics

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %%
driver = webdriver.Chrome()

# %% [markdown]
# Now, Chrome should open a window that looks like this
# (screenshot)

# %%
driver.get("https://analytics.google.com")

# %% [raw]
# <span class="ga-nav-link-label ng-binding ng-scope" ng-class="{'ga-nav-link-no-icon': (!ctrl.noLink &amp;&amp; !ctrl.icon)}">
#   Acquisition
# </span>

# %%
for el in driver.find_elements_by_class_name('ga-nav-link-label'):
    if el.text == 'BEHAVIOR':
        print "clicking on it ... "
        el.click()
        break;
print "done."
# Out:
# clicking on it ...
# done.

# %%
def ga_nav_link_labels(drv):
    lst = [ el.text for el in driver.find_elements_by_class_name('ga-nav-link-label')]
    return filter(lambda s: len(s)>0, lst)

# %%
ga_nav_link_labels(driver)
# Out:
# [u'HOME',
#  u'CUSTOMIZATION',
#  u'REAL-TIME',
#  u'AUDIENCE',
#  u'ACQUISITION',
#  u'BEHAVIOR',
#  u'Overview',
#  u'Behavior Flow',
#  u'Site Content',
#  u'Site Speed',
#  u'Site Search',
#  u'Events',
#  u'Publisher',
#  u'Experiments',
#  u'CONVERSIONS',
#  u'DISCOVER',
#  u'ADMIN']

# %%
def get_ga_nav_link(drv, txt):
    for el in driver.find_elements_by_class_name('ga-nav-link-label'):
        if el.text == txt:
            return el
    return None

# %%
get_ga_nav_link(driver, 'Site Search').click()
get_ga_nav_link(driver, 'Search Terms').click()

# %%
body = driver.find_element_by_tag_name('body')
body.get_attribute('innerHTML')
# Out:
# u'<!-- Google Tag Manager (noscript) --><noscript>&lt;iframe src="https://www.googletagmanager.com/ns.html?id=GTM-NNQJ5LT" height="0" width="0" style="display:none;visibility:hidden;"&gt;&lt;/iframe&gt;</noscript><!-- End Google Tag Manager (noscript) --><style>plaintext{display:none}</style><script>(function() {  try {    var win = this;    while (1) {      if (win.parent == win) {        break;      }      win.frameElement.src.substr(0, 1);      win = win.parent;    }    if (win.frameElement != null) {      throw \'<plaintext>\';    }    document.write(\'\\x3Cxmp style\\x3Ddisplay:none\\x3E\');  } catch(e) {    try {      if (!open(location, \'_top\')) {        alert(\'this content cannot be framed\');      }      top.location = location;    } catch(d) {}  }})();</script><xmp style="display:none"><plaintext/><xmp>.</xmp><iframe id="ga-hist" style="display:none"></iframe><input id="ga-hist-input" type="hidden" value="report/content-site-search-search-terms/a54516992w87479473p92320289/"><div id="main" style="min-width: 1000px;"><div id="ID-headerBar" style="width:100%;min-width:1000px;top:0px;z-index:61"><div id="ID-systemNotification" style="display: none;"><div class="_GAmpb"><table class="_GARFb"><tbody><tr><td class="_GAgpb"><div class="_GAa7"></div></td><td><div id="ID-notificationMessage"></div></td></tr></tbody></table></div></div><div id="ID-announcementNotification" style="display: none;"></div><div id="ID-gmsHeader"><div><div class="gafe ng-scope"><!-- uiView: --><div ui-view="" class="ng-scope"><div class="ng-scope"><div class="ga-loader layout-align-center-center layout-row ng-hide" ng-show="loaderService.canShow()" data-totalrequests="13" layout="row" layout-align="center center" aria-hidden="true">\n  <!-- ngIf: !loaderService.isScionMode() --><div ng-if="!loaderService.isScionMode()" class="ga-loader-inner ng-scope">Loading...</div><!-- end ngIf: !loaderService.isScionMode() -->\n  <!-- ngIf: loaderService.isScionMode() -->\n</div><!-- uiView: --><div ui-view="" class="ng-scope"><!-- uiView: --><ui-view class="ng-scope"><div id="suite-top-nav" show-alerts="ctrl.showAlerts" class="ng-isolate-scope">\n  <suite-header redirect-to-accounts-page="ctrl.redirectToAccountsPage()" is-root-page="ctrl.isRootPage()" navigation-fn="ctrl.navigateTo(location)" class="ng-isolate-scope"><div class="suite gms-header layout-column suite-header-is-ready" ng-class="{\'suite-header-is-ready\': ctrl.suiteHeaderDataService.headerIsReady}" layout="column" md-theme="standard"> <md-toolbar layout="row" class="md-accent _md layout-row md-standard-theme _md-toolbar-transitions" ng-class="{\'gms-header-mobile\': ctrl.isMobile}"> <!-- ngIf: ctrl.suiteHeaderDataService.renderOrgManagementLink() --> <!-- ngIf: !ctrl.hideChip && !ctrl.isMobile --><span ng-if="!ctrl.hideChip &amp;&amp; !ctrl.isMobile" class="ng-scope"> <!-- ngIf: ctrl.renderBackArrow() --> <!-- ngIf: !ctrl.suiteHeaderDataService.data.backArrowDestination --><button class="gms-chip-button gms-chip-icon md-button ng-scope md-standard-theme suite-free-chip" type="button" ng-transclude="" ng-if="!ctrl.suiteHeaderDataService.data.backArrowDestination" ng-click="ctrl.backArrowClicked($event)" ng-class="ctrl.isPremium ? \'suite-premium-chip\' : \'suite-free-chip\'" md-no-ink="" aria-label="Back to Home" gtmtrigger="suite-chip-button"> <!-- ngIf: ctrl.suiteProductDataService.isConfidential() && !ctrl.suiteHeaderDataService.renderProductLockupNoExperiment() --> <img ng-src="//www.gstatic.com/analytics/header/legacy/v1/ic_analytics.svg" alt="Analytics" class="ng-scope" src="//www.gstatic.com/analytics/header/legacy/v1/ic_analytics.svg"> </button><!-- end ngIf: !ctrl.suiteHeaderDataService.data.backArrowDestination --> </span><!-- end ngIf: !ctrl.hideChip && !ctrl.isMobile --> <!-- ngIf: !ctrl.suiteHeaderDataService.renderOrgManagementLink() && ctrl.hideChip --> <div flex="" class="md-toolbar-tools gms-header-toolbar flex"> <!-- ngIf: ctrl.suiteHeaderDataService.renderProductLockup() --> <! ...

# %%
tbl = driver.find_element_by_id('ID-rowTable')
print tbl.id
# Out:
# 0.6139261861771723-2

# %%
import pandas as pd
import StringIO

# %%
tbl_doc = tbl.get_attribute('innerHTML')
print tbl_doc[:100]
# Out:
# <thead><tr class="_GABB"><th class="_GATf _GARIb ACTION-sort TARGET-analytics.query ID-dimension-col

# %%
df = pd.read_html(StringIO.StringIO('<table>%s</table>'%tbl_doc))[0]
print df.shape
df.head()
# Out:
# (5000, 6)
#    Search Query               Clicks    Impressions             CTR  \
# 0           1.0              (other)  1,118(28.96%)  23,045(11.05%)
# 1           2.0  youtube merchandise     256(6.63%)      721(0.35%)
# 2           3.0        youtube merch     211(5.46%)      838(0.40%)
# 3           4.0         youtube shop     148(3.83%)      315(0.15%)
# 4           5.0        youtube store     110(2.85%)      274(0.13%)
#
#   Average Position  Unnamed: 5
# 0            4.85%        22.0
# 1           35.51%         1.0
# 2           25.18%         1.7
# 3           46.98%         1.0
# 4           40.15%         1.0

# %% [markdown]
# # Exercise
#
# The task is to build a script that:
# 1. navigates to the right analysis view (left navigations),
# 2. sets the date range for the analysis by using the date fields in the top right corner, and
# 3. traverses through all pages; meanwhile
# 4. extracts the datatable and downloads
